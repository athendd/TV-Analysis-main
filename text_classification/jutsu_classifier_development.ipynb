# %% [markdown]
# # Load Model

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer
from datasets import Dataset

# %%
data_path = "../Data/jutsus.jsonl"
df = pd.read_json(data_path, lines = True)
df.head()
# Out:
#                                  jutsu_name  \
# 0                      Air Lightning Bullet
# 1                 Adamantine Sealing Chains
# 2  Adamantine Seal: Monkey Yang Suppression
# 3                          Aerobatic Strike
# 4                          Afterimage Clone
#
#                                      jutsu_type  \
# 0                       Taijutsu, Shurikenjutsu
# 1  Hiden, Ninjutsu, Fūinjutsu, Barrier Ninjutsu
# 2     Ninjutsu, Fūinjutsu, Cooperation Ninjutsu
# 3    Scientific Ninja Tool Techniques, Taijutsu
# 4                    Ninjutsu, Clone Techniques
#
#                                    jutsu_description
# 0  The user punches the opponent twice with their...
# 1  This is a sealing technique that is characteri...
# 2  After placing fūinjutsu tags in an area, the u...
# 3  The user sends the opponent in the air, where ...
# 4  Shisui uses the Body Flicker Technique, and mo...

# %%
"""
Removes unncessary jutsus from the jutsu type and only keeps 
Genjutsu, Ninjutsu, Taijutsu
"""
def simplify_jutsu(jutsu):
    if "Genjutsu" in jutsu:
        return "Genjutsu"
    if "Ninjutsu" in jutsu:
        return "Ninjutsu"
    if "Taijutsu" in jutsu:
        return "Taijutsu"

# %%
df['jutsu_type_simplified'] = df['jutsu_type'].apply(simplify_jutsu)

# %%
df.tail()
# Out:
#              jutsu_name jutsu_type  \
# 2934       16 Hit Combo   Taijutsu
# 2935  100% Single Punch   Taijutsu
# 2936  Absorption Sphere   Ninjutsu
# 2937   1000 Metre Punch   Taijutsu
# 2938    100 Metre Punch   Taijutsu
#
#                                       jutsu_description jutsu_type_simplified
# 2934  A very effective move, Ino uses this as a quic...              Taijutsu
# 2935  Tsunade gathers large amounts of chakra in her...              Taijutsu
# 2936  Using the Jutsu Absorption Arm, the user creat...              Ninjutsu
# 2937  The user focuses a large amount of chakra into...              Taijutsu
# 2938  A shorter version of the 1000 Metre Punch, the...              Taijutsu

# %%
#Dataset outputs are skewed with Ninjutsu appearing more often than the other two
df['jutsu_type_simplified'].value_counts()
# Out:
# jutsu_type_simplified
# Ninjutsu    2272
# Taijutsu     398
# Genjutsu     101
# Name: count, dtype: int64

# %%
#Simplify dataset to only have jutsu type and description
df['text'] = df['jutsu_name'] + '. ' + df['jutsu_description']
df['jutsus'] = df['jutsu_type_simplified']
df = df[['text', 'jutsus']]
df = df.dropna()

# %%
df.head()
# Out:
#                                                 text    jutsus
# 0  Air Lightning Bullet. The user punches the opp...  Taijutsu
# 1  Adamantine Sealing Chains. This is a sealing t...  Ninjutsu
# 2  Adamantine Seal: Monkey Yang Suppression. Afte...  Ninjutsu
# 3  Aerobatic Strike. The user sends the opponent ...  Taijutsu
# 4  Afterimage Clone. Shisui uses the Body Flicker...  Ninjutsu

# %%
from bs4 import BeautifulSoup
#Clean the text
class Cleaner():
    def __init__(self):
        pass
    
    def put_line_breaks(self, text):
        return text.replace('<\p>', '<\p>\n')
    
    def remove_html_tags(self, text):
        clean_text = BeautifulSoup(text, 'lxml').text
        
        return clean_text
    
    def clean(self, text):
        text = self.put_line_breaks(text)
        text = self.remove_html_tags(text)
        text = text.strip()
        
        return text
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# <>:8: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\thynnea\AppData\Local\Temp\ipykernel_3408\2582412187.py:8: SyntaxWarning: invalid escape sequence '\p'
#   return text.replace('<\p>', '<\p>\n')
# C:\Users\thynnea\AppData\Local\Temp\ipykernel_3408\2582412187.py:8: SyntaxWarning: invalid escape sequence '\p'
#   return text.replace('<\p>', '<\p>\n')

# %%
text_column_name = 'text'
label_column_name = 'jutsus'

# %%
cleaner = Cleaner()
df['text_cleaned'] = df[text_column_name].apply(cleaner.clean)
# Out:
# C:\Users\thynnea\AppData\Local\Temp\ipykernel_3408\2582412187.py:11: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text, 'lxml').text

# %%
df
# Out:
#                                                    text    jutsus  \
# 0     Air Lightning Bullet. The user punches the opp...  Taijutsu
# 1     Adamantine Sealing Chains. This is a sealing t...  Ninjutsu
# 2     Adamantine Seal: Monkey Yang Suppression. Afte...  Ninjutsu
# 3     Aerobatic Strike. The user sends the opponent ...  Taijutsu
# 4     Afterimage Clone. Shisui uses the Body Flicker...  Ninjutsu
# ...                                                 ...       ...
# 2934  16 Hit Combo. A very effective move, Ino uses ...  Taijutsu
# 2935  100% Single Punch. Tsunade gathers large amoun...  Taijutsu
# 2936  Absorption Sphere. Using the Jutsu Absorption ...  Ninjutsu
# 2937  1000 Metre Punch. The user focuses a large amo...  Taijutsu
# 2938  100 Metre Punch. A shorter version of the 1000...  Taijutsu
#
#                                            text_cleaned
# 0     Air Lightning Bullet. The user punches the opp...
# 1     Adamantine Sealing Chains. This is a sealing t...
# 2     Adamantine Seal: Monkey Yang Suppression. Afte...
# 3     Aerobatic Strike. The user sends the opponent ...
# 4     Afterimage Clone. Shisui uses the Body Flicker...
# ...                                                 ...
# 2934  16 Hit Combo. A very effective move, Ino uses ...
# 2935  100% Single Punch. Tsunade gathers large amoun...
# 2936  Absorption Sphere. Using the Jutsu Absorption ...
# 2937  1000 Metre Punch. The user focuses a large amo...
# 2938  100 Metre Punch. A shorter version of the 1000...
#
# [2771 rows x 3 columns]

# %%
#Encode labels
le = preprocessing.LabelEncoder()
le.fit(df[label_column_name].tolist())
# Out:
# LabelEncoder()

# %%
#Gives each jutsu type a unique numerical label
label_dict = {index: label_name for index, label_name in enumerate(le.__dict__['classes_'].tolist())}
label_dict
# Out:
# {0: 'Genjutsu', 1: 'Ninjutsu', 2: 'Taijutsu'}

# %%
df['label'] = le.transform(df[label_column_name].tolist())

# %%
df.head()
# Out:
#                                                 text    jutsus  \
# 0  Air Lightning Bullet. The user punches the opp...  Taijutsu
# 1  Adamantine Sealing Chains. This is a sealing t...  Ninjutsu
# 2  Adamantine Seal: Monkey Yang Suppression. Afte...  Ninjutsu
# 3  Aerobatic Strike. The user sends the opponent ...  Taijutsu
# 4  Afterimage Clone. Shisui uses the Body Flicker...  Ninjutsu
#
#                                         text_cleaned  label
# 0  Air Lightning Bullet. The user punches the opp...      2
# 1  Adamantine Sealing Chains. This is a sealing t...      1
# 2  Adamantine Seal: Monkey Yang Suppression. Afte...      1
# 3  Aerobatic Strike. The user sends the opponent ...      2
# 4  Afterimage Clone. Shisui uses the Body Flicker...      1

# %%
df_train, df_test = train_test_split(df, test_size = 0.2, stratify = df['label'])

# %%
model_name = 'distilbert/distilbert-base-uncased'

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# c:\Users\thynnea\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\thynnea\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# c:\Users\thynnea\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def preprocess_function(tokenizer, examples):
    return tokenizer(examples['text_cleaned'], truncation = True)

# %%
#Convert dataframe to a hugging face dataset
train_dataset = Dataset.from_pandas(df_train)
test_dataset = Dataset.from_pandas(df_test)

#Tokenize the dataset
tokenized_train = train_dataset.map(lambda examples: preprocess_function(tokenizer, examples), batched = True)
tokenized_test = test_dataset.map(lambda examples: preprocess_function(tokenizer, examples), batched = True)
# Out:
# Map: 100%|██████████| 2216/2216 [00:00<00:00, 12970.76 examples/s]
# Map: 100%|██████████| 555/555 [00:00<00:00, 13863.03 examples/s]
